# %%
import pandas as pd

# %%
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',200)

# %%
df=pd.read_csv('data/survey_results_public.csv',index_col='ResponseId')
schema_df=pd.read_csv('data/survey_results_schema.csv')
# Out:
# C:\Users\Sandeep\AppData\Local\Temp\ipykernel_5868\3396261344.py:1: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data/survey_results_public.csv',index_col='ResponseId')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df.sort_values(by=['Country','CompTotal'],ascending=[True,False])[['Country','CompTotal']].head(100)
# Out:
#                         Country    CompTotal
# ResponseId
# 40307               Afghanistan     700000.0
# 7077                Afghanistan     600000.0
# 45925               Afghanistan     500000.0
# 6010                Afghanistan      70000.0
# 40967               Afghanistan      65000.0
# 7925                Afghanistan      20000.0
# 7167                Afghanistan       5200.0
# 38609               Afghanistan       1000.0
# 6836                Afghanistan          NaN
# 15708               Afghanistan          NaN
# 19816               Afghanistan          NaN
# 27099               Afghanistan          NaN
# 44797               Afghanistan          NaN
# 28588                   Albania   10004806.0
# 37731                   Albania    5732910.0
# 33940                   Albania    1500000.0
# 3888                    Albania    1200000.0
# 2023                    Albania     120000.0
# 3185                    Albania      99999.0
# 35934                   Albania      50000.0
# ...

# %%
#nsmallest and nlargest are two methods to fetch smallest and largest values from a given dataframe.
#If you observe the following, we are calling this method on a series and it only fetches the corresponding series' data.
#Instead in the next cell, when we try to call nlargest on dataframe and mention number of rows and column to be selected based on, it will 
#fetch whole dataframe for nlargest values of that specific column selected.
df['CompTotal'].nlargest(10)
# Out:
# ResponseId
# 4934     5.555556e+74
# 44527    8.000000e+23
# 35765    1.000000e+23
# 28546    9.223372e+18
# 22733    1.000000e+17
# 484      1.000000e+16
# 18755    1.000000e+15
# 39338    9.596957e+11
# 35354    6.500000e+11
# 39350    1.000000e+11
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10,'CompTotal')
# Out:
#                                                    MainBranch  \
# ResponseId
# 4934                           I am a developer by profession
# 44527                          I am a developer by profession
# 35765                          I am a developer by profession
# 28546                                   I am learning to code
# 22733       I work with developers or my work supports dev...
# 484                            I am a developer by profession
# 18755                                   I am learning to code
# 39338                          I am a developer by profession
# 35354                          I am a developer by profession
# 39350                                   I am learning to code
#
#                           Age  \
# ResponseId
# 4934          45-54 years old
# 44527         18-24 years old
# 35765         55-64 years old
# 28546       Prefer not to say
# 22733       65 years or older
# 484           35-44 years old
# 18755       Prefer not to say
# ...

# %%
df.nsmallest(10,'CompTotal')
# Out:
#                                                    MainBranch  \
# ResponseId
# 99          I am not primarily a developer, but I write co...
# 182         I am not primarily a developer, but I write co...
# 216         I am not primarily a developer, but I write co...
# 236                            I am a developer by profession
# 263                            I am a developer by profession
# 319                            I am a developer by profession
# 384         I work with developers or my work supports dev...
# 393         I used to be a developer by profession, but no...
# 418         I used to be a developer by profession, but no...
# 429         I am not primarily a developer, but I write co...
#
#                           Age  \
# ResponseId
# 99            18-24 years old
# 182           18-24 years old
# 216           18-24 years old
# 236           25-34 years old
# 263         65 years or older
# 319           35-44 years old
# 384           18-24 years old
# ...
