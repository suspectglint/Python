# %%
person = {"first":"Sravan Reddy","last":"Rokkam","email":"sravanreddy.rokkam@gmail.com"}

# %%
people = {"first":["Sravan Reddy"],"last":["Rokkam"],"email":["sravanreddy.rokkam@gmail.com"]}

# %%
person
# Out:
# {'first': 'Sravan Reddy',
#  'last': 'Rokkam',
#  'email': 'sravanreddy.rokkam@gmail.com'}

# %%
people
# Out:
# {'first': ['Sravan Reddy'],
#  'last': ['Rokkam'],
#  'email': ['sravanreddy.rokkam@gmail.com']}

# %%
people = {"first":["Sravan Reddy","Cruel","Suspect"],"last":["Rokkam","Goat","Glint"],"email":["sravanreddy.rokkam@gmail.com","cruelgoat@gmail.com","suspectglint@gmail.com"]}

# %%
people
# Out:
# {'first': ['Sravan Reddy', 'Cruel', 'Suspect'],
#  'last': ['Rokkam', 'Goat', 'Glint'],
#  'email': ['sravanreddy.rokkam@gmail.com',
#   'cruelgoat@gmail.com',
#   'suspectglint@gmail.com']}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#           first    last                         email
# 0  Sravan Reddy  Rokkam  sravanreddy.rokkam@gmail.com
# 1         Cruel    Goat           cruelgoat@gmail.com
# 2       Suspect   Glint        suspectglint@gmail.com

# %%
df.head()
# Out:
#           first    last                         email
# 0  Sravan Reddy  Rokkam  sravanreddy.rokkam@gmail.com
# 1         Cruel    Goat           cruelgoat@gmail.com
# 2       Suspect   Glint        suspectglint@gmail.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   3 non-null      object
#  1   last    3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 204.0+ bytes

# %%
df['email']
# Out:
# 0    sravanreddy.rokkam@gmail.com
# 1             cruelgoat@gmail.com
# 2          suspectglint@gmail.com
# Name: email, dtype: object

# %%
df.email
# Out:
# 0    sravanreddy.rokkam@gmail.com
# 1             cruelgoat@gmail.com
# 2          suspectglint@gmail.com
# Name: email, dtype: object

# %%
type(df.email)
# Out:
# pandas.core.series.Series

# %%
df[['first','last']]
# Out:
#           first    last
# 0  Sravan Reddy  Rokkam
# 1         Cruel    Goat
# 2       Suspect   Glint

# %%
type(df[['first','last']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df
# Out:
#           first    last                         email
# 0  Sravan Reddy  Rokkam  sravanreddy.rokkam@gmail.com
# 1         Cruel    Goat           cruelgoat@gmail.com
# 2       Suspect   Glint        suspectglint@gmail.com

# %%
df.iloc[0]
# Out:
# first                    Sravan Reddy
# last                           Rokkam
# email    sravanreddy.rokkam@gmail.com
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[0,1]]
# Out:
#           first    last                         email
# 0  Sravan Reddy  Rokkam  sravanreddy.rokkam@gmail.com
# 1         Cruel    Goat           cruelgoat@gmail.com

# %%
type(df.iloc[[0,1]])
# Out:
# pandas.core.frame.DataFrame

# %%
#We can input the integer labels for iloc in any order and the rows will be fetched in the same order as of input.
df.iloc[[1,0,2]]
# Out:
#           first    last                         email
# 1         Cruel    Goat           cruelgoat@gmail.com
# 0  Sravan Reddy  Rokkam  sravanreddy.rokkam@gmail.com
# 2       Suspect   Glint        suspectglint@gmail.com

# %%
#Here we can use the second list to get the columns in same order mentioned in the columns list.
df.iloc[[0,1],[2,0]]
# Out:
#                           email         first
# 0  sravanreddy.rokkam@gmail.com  Sravan Reddy
# 1           cruelgoat@gmail.com         Cruel

# %%
df.loc[0]
# Out:
# first                    Sravan Reddy
# last                           Rokkam
# email    sravanreddy.rokkam@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[0,2,1]]
# Out:
#           first    last                         email
# 0  Sravan Reddy  Rokkam  sravanreddy.rokkam@gmail.com
# 2       Suspect   Glint        suspectglint@gmail.com
# 1         Cruel    Goat           cruelgoat@gmail.com

# %%
df.loc[[0,1,2]]
# Out:
#           first    last                         email
# 0  Sravan Reddy  Rokkam  sravanreddy.rokkam@gmail.com
# 1         Cruel    Goat           cruelgoat@gmail.com
# 2       Suspect   Glint        suspectglint@gmail.com

# %%
df.loc[[0,1,2],['last','email']]
# Out:
#      last                         email
# 0  Rokkam  sravanreddy.rokkam@gmail.com
# 1    Goat           cruelgoat@gmail.com
# 2   Glint        suspectglint@gmail.com

# %%
df.iloc[0,1]
# Out:
# 'Rokkam'

# %%
type(df.iloc[0,1])
# Out:
# str

# %%
df.loc[2,'email']
# Out:
# 'suspectglint@gmail.com'

# %%
type(df.loc[2,'email'])
# Out:
# str

# %%
df.loc[0:1,'first':'last']
# Out:
#           first    last
# 0  Sravan Reddy  Rokkam
# 1         Cruel    Goat

# %%
#Using slicing in pandas loc method but the last index in slice is inclusive and we need not put the slice in square braces.
df.loc[0:2,['last','email']]
# Out:
#      last                         email
# 0  Rokkam  sravanreddy.rokkam@gmail.com
# 1    Goat           cruelgoat@gmail.com
# 2   Glint        suspectglint@gmail.com

# %%
#And when we use slicing in iloc, the last indices are not inclusive unlike loc()
df.iloc[1:3,1:3]
# Out:
#     last                   email
# 1   Goat     cruelgoat@gmail.com
# 2  Glint  suspectglint@gmail.com

# %%
type(df.loc)
# Out:
# pandas.core.indexing._LocIndexer

# %%
type(df.iloc)
# Out:
# pandas.core.indexing._iLocIndexer
